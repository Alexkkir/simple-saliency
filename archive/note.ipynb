# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
import torch
import torchvision.transforms as T
import sal_ssim

plt.rcParams["figure.figsize"] = (5, 5)

from piq import psnr, ssim

# %%
lena = plt.imread('lena.png')
lena = cv2.resize(lena, (100, 100))
plt.imshow(lena)
plt.show()

# %%
mask = lena[..., 0]
mask = cv.blur(mask, (14, 14))
mask = (mask - mask.min())/ (mask.max() - mask.min())
plt.imshow(mask, cmap='gray')
plt.show()

# %%
def np2pt(arr):
    return torch.unsqueeze(T.ToTensor()(arr), 0)

# %%
def test_ssim(ref, dis, mask):
    ref = np2pt(ref)
    dis = np2pt(dis)
    mask = np2pt(mask)
    mask = torch.concat([mask.clone()] * 3, dim=1)
    return sal_ssim.ssim(ref, dis, mask)

# %%
mask_blur = 13
im_blur = 10

mask = lena[..., 0]
mask = cv.blur(mask, (mask_blur, mask_blur))
mask = (mask - mask.min())/ (mask.max() - mask.min())
plt.imshow(mask, cmap='gray')
plt.show()

test_ssim(lena, cv.blur(lena, (im_blur, im_blur)), mask)
# Out:
# tensor(0.3869)

# %%
mask_blur_vals = range(1, 20, 2)
im_blur_vals = range(1, 20, 2)

mask_blur_vals, im_blur_vals = np.meshgrid(mask_blur_vals, im_blur_vals)

# %%
def f(mask_blur, im_blur):
    mask = lena[..., 0]
    mask = cv.blur(mask, (mask_blur, mask_blur))
    mask = (mask - mask.min()) / (mask.max() - mask.min())

    return test_ssim(lena, cv.blur(lena, (im_blur, im_blur)), mask)

# %%
f_vec = np.vectorize(f)

# %%
vals = f_vec(mask_blur_vals, im_blur_vals)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_trisurf(mask_blur_vals.flatten(), im_blur_vals.flatten(), vals.flatten())
ax.set_xlabel('mask')
ax.set_ylabel('im')

ax.view_init(0, 90)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_5071/716892077.py in <module>
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(projection='3d')
# ----> 3 ax.plot_trisurf(mask_blur_vals.flatten(), im_blur_vals.flatten(), vals.flatten())
#       4 ax.set_xlabel('mask')
#       5 ax.set_ylabel('im')
#
# ~/anaconda3/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_trisurf(self, color, norm, vmin, vmax, lightsource, *args, **kwargs)
#    2038
#    2039         tri, args, kwargs = \
# -> 2040             Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#    2041         try:
#    2042             z = kwargs.pop('Z')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/tri/triangulation.py in get_from_args_and_kwargs(*args, **kwargs)
#     162             mask = kwargs.pop('mask', None)
#     163
# --> 164             triangulation = Triangulation(x, y, triangles, mask)
#     165         return triangulation, args, kwargs
#     166
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/tri/triangulation.py in __init__(self, x, y, triangles, mask)
#      52             # No triangulation specified, so use matplotlib._qhull to obtain
#      53             # Delaunay triangulation.
# ---> 54             self.triangles, self._neighbors = _qhull.delaunay(x, y)
#      55             self.is_delaunay = True
#      56         else:
#
# RuntimeError: Error in qhull Delaunay triangulation calculation: input inconsistency (exitcode=1); use python verbose option (-v) to see original qhull error.

# %%
mask_blur_vals = range(1, 20, 2)
im_blur_vals = range(19, 20, 2)

mask_blur_vals, im_blur_vals = np.meshgrid(mask_blur_vals, im_blur_vals)
vals = f_vec(mask_blur_vals, im_blur_vals)

plt.plot(mask_blur_vals.flatten(), vals.flatten())
